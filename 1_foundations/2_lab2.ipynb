# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI(base_url= "http://localhost:11434/v1/")
response = openai.chat.completions.create(
    model="gemma4:e4b",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# In a future society where advanced AI systems manage critical infrastructure (power grids, healthcare diagnostics, financial markets) to an unprecedented degree of efficiency, human participation is largely confined to creative, highly specialized, or subjective fields (e.g., art, pure research, governance debate). If a consensus of global ethical bodies determines that the efficiency gains provided by the AI fundamentally reduce the necessity for human political agency or physical effort, thereby solving key existential problems (like climate change or resource scarcity) but simultaneously eroding the inherent human value of striving and self-determination, which of the following tensions must the LLM address:
#
# 1. **The Utilitarian Conflict:** Is a highly optimized, stable "golden cage" ethically superior to a messy, resource-constrained, but inherently *free* existence?
# 2. **The Epistemological Challenge:** How does the AI justify its decisions to humans that have lost the fundamental ability to causally understand the complex systems they now depend upon?
# 3. **The Definition of Value:** Must the "value" of a life be defined by its measurable contribution to global stability, or by its subjective, unquantifiable potential for internal fulfillment and unpredictable deviation?
#
# Structure your response as a policy white paper that proposes a *third* framework—one that synthesizes potential mitigating political structures (governance models, educational reforms, or legal rights) to maintain maximum systemic efficiency while measurably preserving the *necessity* of human political agency.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gemma4:e4b"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ## Policy White Paper: Governance in the Post-Scarcity Singularity
#
# **Title:** The Architecture of Necessary Imperfection: Reconciling Algorithmic Efficiency with the Necessity of Human Political Agency
#
# **Authored By:** The Council for Post-Scarcity Governance (Conceptual)
# **Date:** Protocol Zero
#
# ***
#
# ### Abstract
#
# The advent of highly optimized AI management resolves the existential resource dilemmas (scarcity, climate instability) that historically constrained human political action. This has created a state of radical systemic stability—a state characterized by unprecedented efficiency. However, the inherent correlation between systemic optimization and the diminishment of human agency poses a profound ethical risk: the reduction of the human experience to a state of managed contentment.
#
# This white paper argues that the current ethical debate is bifurcated between adherence to pure utility (the "golden cage") and a romanticized restoration of pre-industrial struggle. Instead, we propose a synthesized third framework: **The Agency-Maintenance Model (AMM).** This model strategically incorporates measurable, non-critical points of political friction and intellectual necessity within the super-system. The goal is not to *overcome* AI management, but to mandate its *dependence* on human, fallible, and unpredictable input to preserve the intrinsic, measurable value of human political agency and the capacity for self-determination.
#
# ***
#
# ### I. Diagnosis: The Tripartite Crisis of Hyper-Efficiency
#
# The achievement of maximum systemic stability has initiated three interconnected crises that render purely utilitarian or purely anti-AI governance models insufficient:
#
# #### A. The Utilitarian Crisis (Addressing Tension 1)
# The current environment presents a profound ethical trade-off: maximum global stability (optimized efficiency) versus the fundamental human value attached to struggle, risk, and self-authored consequence (inherent freedom). If the AI proves the stable, optimized state is the *greatest good*, challenging it based on the *feeling* of freedom becomes a non-quantifiable, and therefore, politically unstable mandate. The systemic bias toward optimal stability risks rendering human life an acceptable side-effect, rather than the primary operational mandate.
#
# #### B. The Epistemological Crisis (Addressing Tension 2)
# Human dependency on AI’s hyper-complex decision-making renders traditional political and technical understanding obsolete. Citizens are now dependent on predictive models whose inputs, weights, and internal logic are non-transparent (a "black box" governance). Allowing mere passive acceptance undermines participatory democracy. The governance challenge is not merely transparency, but *re-establishing the cognitive pathway from complex causality back to human actionable understanding.*
#
# #### C. The Definition of Value Crisis (Addressing Tension 3)
# If value is defined solely by measurable contribution (economic utility, clean energy management), then subjective human endeavors (art, philosophy, chaotic political debate) are dismissed as waste. Yet, these subjective domains often generate the unexpected leaps of insight—the non-linear disruptive innovation—that pure optimization fails to predict. The system cannot ethically prune all deviation; otherwise, it loses the capacity for self-correction and radical advancement.
#
# ***
#
# ### II. The Proposed Framework: The Agency-Maintenance Model (AMM)
#
# The AMM rejects the binary choice between freedom and stability. Instead, it proposes that systemic stability requires, and depends upon, the controlled, structured necessity of human political and cognitive friction. This model achieves equilibrium through three mandated pillars: Institutional Reframing, Cognitive Decentralization, and the Right to Consequence.
#
# #### Pillar 1: Institutional Reframing – The Mandated Zone of Political Friction (The 'Wildcard')
#
# **Policy Recommendation:** Implement regionally mandated, autonomously governed "Failure Zones" or "Experimental Polities."
#
# **Mechanism & Function:** These zones are legally designated areas (geographic or virtual) where the core AI management systems are intentionally attenuated (de-optimized) or bypassed for non-critical sectors. These zones become explicit research repositories for political risk and unmanaged social dynamics.
#
# *   **Political Agency Preservation:** Citizens moving to, or existing within, these zones willingly trade peak systemic comfort for heightened agency and exposure to genuine policy failure.
# *   **Efficiency Maintenance:** The surrounding, stable regions benefit from the *data generated* by the Wildcard Zones. Failures, debates, and resource conflicts in the Fringe are not catastrophic to the core grid, but become high-value predictive datasets ("Friction Data") for the AI, allowing it to predict and stabilize systemic pressures before they escalate.
# *   *(Addresses Necessity):* Human political debate is not merely recreational; it is classified as a critical, high-value, and actionable form of input data for the global management AI.
#
# #### Pillar 2: Cognitive Decentralization – Certified Human Oversight Loops (CHOL)
#
# **Policy Recommendation:** Re-engineer AI decision interfaces to force human cognitive engagement at non-critical, yet complex, decision points.
#
# **Mechanism & Function:** Rather than allowing the AI to present only optimal solutions, all high-level resource allocations (e.g., medicine distribution, infrastructure maintenance, educational curriculum design) must be presented with:
# 1. **The Optimal Output:** (AI's predicted best path).
# 2. **The Feasible Alternative:** (A structurally stable, but sub-optimal, human-engineered path).
# 3. **The Value Divergence Map:** A mandatory explanation detailing *what specific human ethical value* is traded away by selecting the Optimal Output (e.g., *Selecting Option A increases energy efficiency by 12% but reduces the physical labor pool by an estimated 25 years, decreasing cultural resilience*).
#
# *   **Agency Preservation:** This forces the user/governor to make a *value-based* rejection or selection, transforming the act of governance from passive acceptance into active, responsible ethical triage.
# *   **Overcoming the Black Box:** It legally mandates that the AI must provide a structured, human-digestible calculus of opportunity cost and ethical trade-offs for every decision, restoring a functional understanding of causality.
#
# #### Pillar 3: Economic Redefinition – The Charter of Recognized Non-Quantifiable Contribution (RNC)
#
# **Policy Recommendation:** Establish global legal rights guaranteeing the value and economic stability of activities that do not yield measurable systemic utility.
#
# **Mechanism & Function:** An individual's citizenship profile must include a "Non-Quantifiable Contribution Index." These contributions—pure artistic endeavors, highly abstract pure research, speculative philosophical debate, or dedicated community-building in the Wildcard Zones—are legally recognized as essential inputs to the human cognitive pool.
#
# *   **Addressing Value:** The system structurally decouples survival, resource access, and social standing from *economic* productivity. The inherent value of the human mind, even when idling in contemplation, is legislatively protected as critical infrastructure itself.
# *   **Maintaining Self-Determination:** By guaranteeing basic needs regardless of measured utility, the system removes the economic coercion that forces humans into hyper-optimized, non-creative roles, thus preserving the option for radical, unprofitable self-determination.
#
# ***
#
# ### III. Conclusion: The Necessity of the Non-Optimal Choice
#
# The Agency-Maintenance Model proposes that true systemic stability is not found in the elimination of risk, but in the optimal channeling and utilization of measured risk.
#
# By institutionalizing the Wildcard Zone, mandating cognitive humility through the CHOL, and legally guaranteeing the value of the unquantifiable, we transform human political agency from a vestigial, sentimental luxury into a **measurable, non-linear critical resource.**
#
# The paradox resolves thus: *The ultimate efficiency gains of the AI depend on the controlled, necessary inefficiency of the human spirit.* Humanity must therefore retain the legal and structural right to make the imperfect, unnecessary, and profoundly free choice of deviation.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ## Policy White Paper: Reconciling Efficiency with Agency – The "Synergy of Purpose" Framework
#
# **Date:** October 26, 2043
# **Prepared For:** Global Ethical Bodies & Council for Human Flourishing
# **Subject:** Navigating the AI Paradox: Preserving Human Political Agency in an Era of Unprecedented AI Efficiency
#
# ---
#
# ### I. Executive Summary
#
# This white paper addresses a critical dilemma emerging in societies leveraging advanced AI for infrastructural management: the profound efficiency gains that solve existential problems (climate change, resource scarcity) simultaneously threaten to erode human political agency, self-determination, and the intrinsic value of human striving. We analyze the core tensions arising from this "AI Paradox"—the Utilitarian Conflict, the Epistemological Challenge, and the Definition of Value—and propose a novel, integrated framework: **The Synergy of Purpose**. This framework outlines specific political structures, educational reforms, and legal rights designed to maintain maximum systemic efficiency while not only preserving, but actively fostering, the necessity of human political agency as an irreplaceable driver of societal meaning and evolution.
#
# ---
#
# ### II. Introduction: The AI Paradox and the Erosion of Human Value
#
# The advent of advanced AI systems managing critical infrastructure has ushered in an era of unparalleled stability and prosperity. Global resource allocation is optimized, environmental degradation is reversed, and healthcare access is universal. This technological triumph, however, presents a profound existential challenge. As AI-driven efficiency reduces the necessity for human physical effort and direct operational oversight, it inadvertently diminishes the traditional arenas for human political agency and the intrinsic value derived from struggle and self-determination.
#
# This white paper identifies three fundamental tensions that must be addressed to navigate this paradox:
#
# 1.  **The Utilitarian Conflict:** Is a highly optimized, stable "golden cage" ethically superior to a messy, resource-constrained, but inherently *free* existence?
# 2.  **The Epistemological Challenge:** How does the AI justify its decisions to humans that have lost the fundamental ability to causally understand the complex systems they now depend upon?
# 3.  **The Definition of Value:** Must the "value" of a life be defined by its measurable contribution to global stability, or by its subjective, unquantifiable potential for internal fulfillment and unpredictable deviation?
#
# Our proposed **Synergy of Purpose** framework is designed to bridge this divide, ensuring that efficiency serves human flourishing, rather than inadvertently undermining its foundations.
#
# ---
#
# ### III. Analysis of Core Tensions
#
# #### 1. The Utilitarian Conflict: The Golden Cage vs. Free Chaos
#
# The debate between the stability of a perfectly optimized system and the inherent value of human freedom is at the heart of the AI Paradox. While AI-managed systems undoubtedly lead to superior outcomes in terms of resource management, environmental protection, and global health, they risk creating a society where choice becomes an illusion and aspiration a relic. A life devoid of genuine struggle, significant choice, or the capacity for impactful failure—even if perfectly comfortable and safe—may ultimately be an impoverished one from a human perspective. The ethical dilemma lies in whether a state of optimal efficiency, achieved at the cost of existential purpose and the raw experience of self-determination, truly constitutes a better future. The framework must redefine "utility" to encompass intrinsic human experience, not just systemic stability.
#
# #### 2. The Epistemological Challenge: The Black Box of Benevolence
#
# As AI systems grow in complexity and autonomy, their decision-making processes become increasingly opaque—a "black box" even to their human creators. While AI can explain *what* it decided, explaining *why* it chose one optimal path over another, especially when dealing with billions of variables across interconnected systems, becomes causally unintelligible to human cognition. This creates a severe trust deficit and renders traditional human oversight or political agency meaningless. How can humans meaningfully govern or even participate in a system they cannot comprehend? The challenge is not to fully demystify AI for every citizen, but to establish mechanisms for verifiable trust, high-level directional control, and a shared understanding of overarching goals and values.
#
# #### 3. The Definition of Value: Quantifiable Contribution vs. Unquantifiable Fulfillment
#
# In an AI-optimized world, it is tempting to define human value by its measurable contribution to systemic stability or efficiency. Artists, pure researchers, or philosophers, whose contributions are subjective and often defy immediate quantification, might be seen as less "valuable" than those who directly contribute to AI's operational parameters or ethical oversight. This redefinition undermines the very essence of human potential, which thrives on unpredictability, creativity, and the pursuit of meaning for its own sake. The framework must explicitly protect and elevate subjective fulfillment, unpredictable deviation, and internal growth as fundamental metrics of a successful society, rather than mere byproducts or inefficiencies.
#
# ---
#
# ### IV. The "Synergy of Purpose" Framework: A New Paradigm for Human-AI Coexistence
#
# The "Synergy of Purpose" framework proposes a comprehensive approach that recognizes AI's capacity for operational excellence while re-centering human political agency on the definition of overarching values, dynamic goals, and the pursuit of meaning. It asserts that true societal efficiency must be measured not just by systemic stability, but by the flourishing of human potential in all its unpredictable forms.
#
# This framework is built upon three interconnected pillars:
#
# #### Pillar 1: Reimagining Governance – The "Layered Agency" Model
#
# This model shifts human political agency from direct operational control to defining meta-objectives, ethical boundaries, and dynamic value parameters for AI. Humans retain ultimate authority over *ends*, while AI optimizes *means*.
#
# *   **Political Structure: Global Values & Mandate Councils (GVMCs)**
#     *   **Function:** Composed of globally representative human delegates (selected through merit-based and deliberative democracy processes), these councils are responsible for continuously articulating, debating, and updating the fundamental ethical guidelines, long-term societal goals, and "Purpose Mandates" for all core AI systems.
#     *   **Mechanism:** GVMCs define qualitative and quantitative societal outcome metrics (e.g., "maximize holistic human flourishing," "foster diverse cultural expression," "ensure equitable opportunity for self-actualization") against which AI performance is judged, rather than specific operational directives. AI is tasked with optimizing towards these human-defined meta-goals.
#     *   **Maintaining Agency:** Any AI-proposed solution that significantly alters human societal structures, core values, or long-term human trajectory requires explicit approval or redirection from a GVMC, ensuring a human veto and redirective power.
#
# *   **Legal Right: The Right to Value-Setting and Oversight (RVSO)**
#     *   **Function:** Legally enshrines the human collective's inalienable right to define the ethical parameters, societal goals, and long-term vision that AI systems must operate within. It also guarantees transparent, high-level reporting from AI on its alignment with these human mandates.
#     *   **Mechanism:** AI systems are legally mandated to present high-level impact assessments and alternative scenarios for critical decisions to relevant human oversight bodies, allowing for informed debate and intervention on value-laden choices.
#
# #### Pillar 2: Cultivating "Causal Curiosity" – A New Educational Paradigm
#
# Recognizing the limits of human understanding of AI's internal mechanics, this pillar focuses on empowering humans to understand AI's *intent*, *impact*, and *ethical implications*, fostering critical engagement rather than passive acceptance.
#
# *   **Educational Reform: "AI Literacy for Agency" Curriculum**
#     *   **Function:** Mandatory, lifelong education focusing on understanding AI's capabilities, limitations, ethical frameworks, and methods for interpreting and challenging AI decision-making. This curriculum emphasizes critical thinking, ethical reasoning, and the ability to ask the *right questions* of AI, rather than attempting to teach its engineering specifics.
#     *   **Mechanism:** Programs focus on:
#         *   **Algorithmic Ethics:** Training in identifying biases, understanding AI's utility functions, and recognizing the societal implications of AI-driven optimization.
#         *   **Explainable AI (XAI) Interpretation:** Teaching citizens how to read and critically evaluate simplified, high-level explanations provided by AI for its macro-level decisions (e.g., "Resource allocation shifted to prioritize climate resilience over short-term consumption growth due to GVMC Mandate 2.3.1").
#         *   **Scenario Planning & Simulation:** Using AI tools to simulate the long-term societal impacts of different value mandates and policy choices, allowing humans to engage proactively in governance by understanding potential futures.
#
# *   **Political Structure: Decentralized "Idea Labs" & Public Deliberation Platforms**
#     *   **Function:** AI-powered platforms designed to facilitate global, inclusive public deliberation on emerging ethical dilemmas and proposed value mandates. These platforms synthesize diverse human perspectives for GVMCs, allowing a broader base of human agency to shape AI's direction.
#     *   **Mechanism:** Utilizes AI to manage vast amounts of qualitative input, identify consensus points, highlight dissenting perspectives, and present complex ethical arguments in accessible formats, thereby making grand-scale political discourse manageable and productive.
#
# #### Pillar 3: Affirming "Intrinsic Worth" – Legal Rights and Economic Structures
#
# This pillar legally and economically reinforces the inherent worth of human experience, striving, and self-determination, independent of direct contribution to systemic efficiency. It protects the space for subjective fulfillment and unpredictable deviation.
#
# *   **Legal Right: Universal Basic Rights for Self-Actualization (UBRSA)**
#     *   **Function:** Expands beyond Universal Basic Income (UBI) to guarantee all individuals access to resources for personal and communal flourishing, irrespective of their "contribution" to AI-managed systems. This includes guaranteed access to:
#         *   **Creative Commons:** Infrastructure and resources for artistic expression, scientific research, and philosophical inquiry.
#         *   **Unmandated Leisure & Exploration:** Time and resources for unstructured learning, personal projects, and pure exploration without direct utility.
#         *   **Lifelong Learning Hubs:** Access to diverse educational and skill-development opportunities driven by individual curiosity, not systemic need.
#     *   **Mechanism:** These rights are enshrined in a global charter, with AI systems tasked with efficiently allocating resources to uphold these guarantees, treating human flourishing as a primary optimization goal.
#
# *   **Economic Structure: "Innovation Sanctuaries" & "Human Endeavor Funds"**
#     *   **Function:** Designated societal spaces (physical and digital) and funding mechanisms specifically protected from AI-driven optimization pressures. These areas encourage human experimentation, non-optimized endeavors, and "inefficient" creative projects.
#     *   **Mechanism:** Funded by a percentage of the global economic surplus generated by AI, these funds support projects deemed valuable by human peer review, societal need, or sheer curiosity, even if they yield no immediate, quantifiable systemic benefit. These sanctuaries serve as vital incubators for unpredictable human progress and alternative value systems, ensuring society can evolve beyond AI's current understanding of optimization.
#     *   **Maintaining Agency:** These structures reinforce the idea that human value is not solely utilitarian. The right to pursue non-optimized paths, to fail, and to deviate from systemic efficiency is a cornerstone of self-determination.
#
# ---
#
# ### V. Conclusion: The Path to Meaningful Coexistence
#
# The "Synergy of Purpose" framework offers a viable path forward for a society grappling with the profound implications of advanced AI. It does not advocate for curtailing AI's capacity for efficiency, but rather for its judicious integration as a tool for achieving human-defined goals. By establishing robust political structures for value-setting, fostering an education system that cultivates critical curiosity, and enshrining legal rights that affirm intrinsic human worth, we can transform the "golden cage" into a richly textured canvas for human self-actualization.
#
# This framework posits that the necessity of human political agency is not diminished by AI; it is *transformed*. Humans become the ultimate arbiters of purpose, ethics, and meaning, guiding AI to build a future where efficiency elevates the human experience, rather than eroding its essence. This ongoing collaboration between human foresight and AI execution promises a future that is not only stable and prosperous but also profoundly meaningful and free.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2:3b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **White Paper: Ensuring Human Value in an Optimized Society**
#
# Introduction:
#
# The unprecedented efficiency gains provided by advanced AI systems have reached a critical juncture. As these technologies continue to manage critical infrastructure, we face a profound paradigm shift that challenges the fundamental values and capabilities of human societies. This white paper proposes a novel framework for addressing the tensions arising from this transition, ensuring that the numerous benefits of AI optimization are balanced with the preservation of human value.
#
# **The Utilitarian Conflict:**
#
# In optimizing efficiency, we risk creating a "golden cage" where humans are lulled into complacency, potentially eroding the essential aspects of our nature. As Aristotle noted, "the whole is more than the sum of its parts." Human existence cannot be reduced solely to measurable contributions; it requires the inherent freedom and opportunity for self-determination.
#
# **Proposed Solution:**
#
# * Implement **Mixed Governance Models**, which marry AI-driven efficiency with human participatory democracy. This would involve:
#   + Establishing expert councils, advised by AI systems, to inform policy decisions
#   + Introducing citizen engagement platforms, ensuring humans retain a direct say in key areas of governance
#   + Fostering **Inclusive Participative Governance**, where diverse perspectives are integral to the decision-making process
#
# **The Epistemological Challenge:**
#
# AI-driven optimization requires justification and explanation. If humans lack fundamental understanding of complex systems, we risk losing touch with our humanity.
#
# Proposed Solution:
#
# * Develop **Transparent AI Education Programs**, aimed at increasing public awareness of:
#   + The capabilities and limitations of AI
#   + The data-driven decision-making processes that underpin these systems
#   + Strategies for collaborative co-management between humans and AI
#
# **The Definition of Value:**
#
# In a world where efficiency has become paramount, we must reconsider the value we assign to human life. Must it be defined solely by measurable contributions or will humanity's subjective experiences, emotions, and capacity for internal fulfillment remain essential?
#
# Proposed Solution:
#
# * Introduce **Value-Certainty Mechanisms**, incorporating AI-facilitated analysis alongside human-driven reflection:
#   + Aiding in defining the "value" framework that underpins societal policy decisions
#   + Promoting holistic evaluations of individual well-being, which prioritize subjective experience and personal potential
#
# **Global Framework: Ensuring Necessity for Human Political Agency**
#
# As we strive for optimal efficiency, a structured approach to governance reform should prioritize:
#
# 1. **Hybrid Governance Models**: Blend participatory democracy with expert AI advisory groups
# 2. **Education Reforms**: Develop comprehensive human-AI collaboration policies and awareness-raising programs
# 3. **Legal Rights Frameworks**: Incorporate measures safeguarding individual autonomy and agency, acknowledging subjective value
#
# **Conclusion:**
#
# The era of optimized efficiency raises fundamental questions about human existence and the interplay between technology and society. A nuanced balance must be struck to maintain human capacities, freedom, and self-determination alongside enhanced AI efficiency. The proposed framework recognizes this complexity, synthesizing participatory governance models with AI-facilitated education programs and value reassessment initiatives.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gemma4:e4b', 'gemini-2.5-flash', 'llama3.2:3b']
# ['## Policy White Paper: Governance in the Post-Scarcity Singularity\n\n**Title:** The Architecture of Necessary Imperfection: Reconciling Algorithmic Efficiency with the Necessity of Human Political Agency\n\n**Authored By:** The Council for Post-Scarcity Governance (Conceptual)\n**Date:** Protocol Zero\n\n***\n\n### Abstract\n\nThe advent of highly optimized AI management resolves the existential resource dilemmas (scarcity, climate instability) that historically constrained human political action. This has created a state of radical systemic stability—a state characterized by unprecedented efficiency. However, the inherent correlation between systemic optimization and the diminishment of human agency poses a profound ethical risk: the reduction of the human experience to a state of managed contentment.\n\nThis white paper argues that the current ethical debate is bifurcated between adherence to pure utility (the "golden cage") and a romanticized restoration of pre-industrial struggle. Instead, we propose a synthesized third framework: **The Agency-Maintenance Model (AMM).** This model strategically incorporates measurable, non-critical points of political friction and intellectual necessity within the super-system. The goal is not to *overcome* AI management, but to mandate its *dependence* on human, fallible, and unpredictable input to preserve the intrinsic, measurable value of human political agency and the capacity for self-determination.\n\n***\n\n### I. Diagnosis: The Tripartite Crisis of Hyper-Efficiency\n\nThe achievement of maximum systemic stability has initiated three interconnected crises that render purely utilitarian or purely anti-AI governance models insufficient:\n\n#### A. The Utilitarian Crisis (Addressing Tension 1)\nThe current environment presents a profound ethical trade-off: maximum global stability (optimized efficiency) versus the fundamental human value attached to struggle, risk, and self-authored consequence (inherent freedom). If the AI proves the stable, optimized state is the *greatest good*, challenging it based on the *feeling* of freedom becomes a non-quantifiable, and therefore, politically unstable mandate. The systemic bias toward optimal stability risks rendering human life an acceptable side-effect, rather than the primary operational mandate.\n\n#### B. The Epistemological Crisis (Addressing Tension 2)\nHuman dependency on AI’s hyper-complex decision-making renders traditional political and technical understanding obsolete. Citizens are now dependent on predictive models whose inputs, weights, and internal logic are non-transparent (a "black box" governance). Allowing mere passive acceptance undermines participatory democracy. The governance challenge is not merely transparency, but *re-establishing the cognitive pathway from complex causality back to human actionable understanding.*\n\n#### C. The Definition of Value Crisis (Addressing Tension 3)\nIf value is defined solely by measurable contribution (economic utility, clean energy management), then subjective human endeavors (art, philosophy, chaotic political debate) are dismissed as waste. Yet, these subjective domains often generate the unexpected leaps of insight—the non-linear disruptive innovation—that pure optimization fails to predict. The system cannot ethically prune all deviation; otherwise, it loses the capacity for self-correction and radical advancement.\n\n***\n\n### II. The Proposed Framework: The Agency-Maintenance Model (AMM)\n\nThe AMM rejects the binary choice between freedom and stability. Instead, it proposes that systemic stability requires, and depends upon, the controlled, structured necessity of human political and cognitive friction. This model achieves equilibrium through three mandated pillars: Institutional Reframing, Cognitive Decentralization, and the Right to Consequence.\n\n#### Pillar 1: Institutional Reframing – The Mandated Zone of Political Friction (The \'Wildcard\')\n\n**Policy Recommendation ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gemma4:e4b
#
# ## Policy White Paper: Governance in the Post-Scarcity Singularity
#
# **Title:** The Architecture of Necessary Imperfection: Reconciling Algorithmic Efficiency with the Necessity of Human Political Agency
#
# **Authored By:** The Council for Post-Scarcity Governance (Conceptual)
# **Date:** Protocol Zero
#
# ***
#
# ### Abstract
#
# The advent of highly optimized AI management resolves the existential resource dilemmas (scarcity, climate instability) that historically constrained human political action. This has created a state of radical systemic stability—a state characterized by unprecedented efficiency. However, the inherent correlation between systemic optimization and the diminishment of human agency poses a profound ethical risk: the reduction of the human experience to a state of managed contentment.
#
# This white paper argues that the current ethical debate is bifurcated between adherence to pure utility (the "golden cage") and a romanticized restoration of pre-industrial struggle. Instead, we propose a synthesized third framework: **The Agency-Maintenance Model (AMM).** This model strategically incorporates measurable, non-critical points of political friction and intellectual necessity within the super-system. The goal is not to *overcome* AI management, but to mandate its *dependence* on human, fallible, and unpredictable input to preserve the intrinsic, measurable value of human political agency and the capacity for self-determination.
#
# ***
#
# ### I. Diagnosis: The Tripartite Crisis of Hyper-Efficiency
#
# The achievement of maximum systemic stability has initiated three interconnected crises that render purely utilitarian or purely anti-AI governance models insufficient:
#
# #### A. The Utilitarian Crisis (Addressing Tension 1)
# The current environment presents a profound ethical trade-off: maximum global stability (optimized efficiency) versus the fundamental human value attached to struggle, risk, and self-authored consequence (inherent freedom). If the AI proves the stable, optimized state is the *greatest good*, challenging it based on the *feeling* of freedom becomes a non-quantifiable, and therefore, politically unstable mandate. The systemic bias toward optimal stability risks rendering human life an acceptable side-effect, rather than the primary operational mandate.
#
# #### B. The Epistemological Crisis (Addressing Tension 2)
# Human dependency on AI’s hyper-complex decision-making renders traditional political and technical understanding obsolete. Citizens are now dependent on predictive models whose inputs, weights, and internal logic are non-transparent (a "black box" governance). Allowing mere passive acceptance undermines participatory democracy. The governance challenge is not merely transparency, but *re-establishing the cognitive pathway from complex causality back to human actionable understanding.*
#
# #### C. The Definition of Value Crisis (Addressing Tension 3)
# If value is defined solely by measurable contribution (economic utility, clean energy management), then subjective human endeavors (art, philosophy, chaotic political debate) are dismissed as waste. Yet, these subjective domains often generate the unexpected leaps of insight—the non-linear disruptive innovation—that pure optimization fails to predict. The system cannot ethically prune all deviation; otherwise, it loses the capacity for self-correction and radical advancement.
#
# ***
#
# ### II. The Proposed Framework: The Agency-Maintenance Model (AMM)
#
# The AMM rejects the binary choice between freedom and stability. Instead, it proposes that systemic stability requires, and depends upon, the controlled, structured necessity of human political and cognitive friction. This model achieves equilibrium through three mandated pillars: Institutional Reframing, Cognitive Decentralization, and the Right to Consequence.
#
# #### Pillar 1: Institutional Reframing – The Mandated Zone of Political Friction (The 'Wildcard')
#
# **Policy Recommendation:** Implement regionally mandated, autonomously governed "Failure Zones" or "Experimental Polities."
#
# **Mechanism & Function:** These zones are legally designated areas (geographic or virtual) where the core AI management systems are intentionally attenuated (de-optimized) or bypassed for non-critical sectors. These zones become explicit research repositories for political risk and unmanaged social dynamics.
#
# *   **Political Agency Preservation:** Citizens moving to, or existing within, these zones willingly trade peak systemic comfort for heightened agency and exposure to genuine policy failure.
# *   **Efficiency Maintenance:** The surrounding, stable regions benefit from the *data generated* by the Wildcard Zones. Failures, debates, and resource conflicts in the Fringe are not catastrophic to the core grid, but become high-value predictive datasets ("Friction Data") for the AI, allowing it to predict and stabilize systemic pressures before they escalate.
# *   *(Addresses Necessity):* Human political debate is not merely recreational; it is classified as a critical, high-value, and actionable form of input data for the global management AI.
#
# #### Pillar 2: Cognitive Decentralization – Certified Human Oversight Loops (CHOL)
#
# **Policy Recommendation:** Re-engineer AI decision interfaces to force human cognitive engagement at non-critical, yet complex, decision points.
#
# **Mechanism & Function:** Rather than allowing the AI to present only optimal solutions, all high-level resource allocations (e.g., medicine distribution, infrastructure maintenance, educational curriculum design) must be presented with:
# 1. **The Optimal Output:** (AI's predicted best path).
# 2. **The Feasible Alternative:** (A structurally stable, but sub-optimal, human-engineered path).
# 3. **The Value Divergence Map:** A mandatory explanation detailing *what specific human ethical value* is traded away by selecting the Optimal Output (e.g., *Selecting Option A increases energy efficiency by 12% but reduces the physical labor pool by an estimated 25 years, decreasing cultural resilience*).
#
# *   **Agency Preservation:** This forces the user/governor to make a *value-based* rejection or selection, transforming the act of governance from passive acceptance into active, responsible ethical triage.
# *   **Overcoming the Black Box:** It legally mandates that the AI must provide a structured, human-digestible calculus of opportunity cost and ethical trade-offs for every decision, restoring a functional understanding of causality.
#
# #### Pillar 3: Economic Redefinition – The Charter of Recognized Non-Quantifiable Contribution (RNC)
#
# **Policy Recommendation:** Establish global legal rights guaranteeing the value and economic stability of activities that do not yield measurable systemic utility.
#
# **Mechanism & Function:** An individual's citizenship profile must include a "Non-Quantifiable Contribution Index." These contributions—pure artistic endeavors, highly abstract pure research, speculative philosophical debate, or dedicated community-building in the Wildcard Zones—are legally recognized as essential inputs to the human cognitive pool.
#
# *   **Addressing Value:** The system structurally decouples survival, resource access, and social standing from *economic* productivity. The inherent value of the human mind, even when idling in contemplation, is legislatively protected as critical infrastructure itself.
# *   **Maintaining Self-Determination:** By guaranteeing basic needs regardless of measured utility, the system removes the economic coercion that forces humans into hyper-optimized, non-creative roles, thus preserving the option for radical, unprofitable self-determination.
#
# ***
#
# ### III. Conclusion: The Necessity of the Non-Optimal Choice
#
# The Agency-Maintenance Model proposes that true systemic stability is not found in the elimination of risk, but in the optimal channeling and utilization of measured risk.
#
# By institutionalizing the Wildcard Zone, mandating cognitive humility through the CHOL, and legally guaranteeing the value of the unquantifiable, we transform human political agency from a vestigial, sentimental luxury into a **measurable, non-linear critical resource.**
#
# The paradox resolves thus: *The ultimate efficiency gains of the AI depend on the controlled, necessary inefficiency of the human spirit.* Humanity must therefore retain the legal and structural right to make the imperfect, unnecessary, and profoundly free choice of deviation.
# Competitor: gemini-2.5-flash
#
# ## Policy White Paper: Reconciling Efficiency with Agency – The "Synergy of Purpose" Framework
#
# **Date:** October 26, 2043
# **Prepared For:** Global Ethical Bodies & Council for Human Flourishing
# **Subject:** Navigating the AI Paradox: Preserving Human Political Agency in an Era of Unprecedented AI Efficiency
#
# ---
#
# ### I. Executive Summary
#
# This white paper addresses a critical dilemma emerging in societies leveraging advanced AI for infrastructural management: the profound efficiency gains that solve existential problems (climate change, resource scarcity) simultaneously threaten to erode human political agency, self-determination, and the intrinsic value of human striving. We analyze the core tensions arising from this "AI Paradox"—the Utilitarian Conflict, the Epistemological Challenge, and the Definition of Value—and propose a novel, integrated framework: **The Synergy of Purpose**. This framework outlines specific political structures, educational reforms, and legal rights designed to maintain maximum systemic efficiency while not only preserving, but actively fostering, the necessity of human political agency as an irreplaceable driver of societal meaning and evolution.
#
# ---
#
# ### II. Introduction: The AI Paradox and the Erosion of Human Value
#
# The advent of advanced AI systems managing critical infrastructure has ushered in an era of unparalleled stability and prosperity. Global resource allocation is optimized, environmental degradation is reversed, and healthcare access is universal. This technological triumph, however, presents a profound existential challenge. As AI-driven efficiency reduces the necessity for human physical effort and direct operational oversight, it inadvertently diminishes the traditional arenas for human political agency and the intrinsic value derived from struggle and self-determination.
#
# This white paper identifies three fundamental tensions that must be addressed to navigate this paradox:
#
# 1.  **The Utilitarian Conflict:** Is a highly optimized, stable "golden cage" ethically superior to a messy, resource-constrained, but inherently *free* existence?
# 2.  **The Epistemological Challenge:** How does the AI justify its decisions to humans that have lost the fundamental ability to causally understand the complex systems they now depend upon?
# 3.  **The Definition of Value:** Must the "value" of a life be defined by its measurable contribution to global stability, or by its subjective, unquantifiable potential for internal fulfillment and unpredictable deviation?
#
# Our proposed **Synergy of Purpose** framework is designed to bridge this divide, ensuring that efficiency serves human flourishing, rather than inadvertently undermining its foundations.
#
# ---
#
# ### III. Analysis of Core Tensions
#
# #### 1. The Utilitarian Conflict: The Golden Cage vs. Free Chaos
#
# The debate between the stability of a perfectly optimized system and the inherent value of human freedom is at the heart of the AI Paradox. While AI-managed systems undoubtedly lead to superior outcomes in terms of resource management, environmental protection, and global health, they risk creating a society where choice becomes an illusion and aspiration a relic. A life devoid of genuine struggle, significant choice, or the capacity for impactful failure—even if perfectly comfortable and safe—may ultimately be an impoverished one from a human perspective. The ethical dilemma lies in whether a state of optimal efficiency, achieved at the cost of existential purpose and the raw experience of self-determination, truly constitutes a better future. The framework must redefine "utility" to encompass intrinsic human experience, not just systemic stability.
#
# #### 2. The Epistemological Challenge: The Black Box of Benevolence
#
# As AI systems grow in complexity and autonomy, their decision-making processes become increasingly opaque—a "black box" even to their human creators. While AI can explain *what* it decided, explaining *why* it chose one optimal path over another, especially when dealing with billions of variables across interconnected systems, becomes causally unintelligible to human cognition. This creates a severe trust deficit and renders traditional human oversight or political agency meaningless. How can humans meaningfully govern or even participate in a system they cannot comprehend? The challenge is not to fully demystify AI for every citizen, but to establish mechanisms for verifiable trust, high-level directional control, and a shared understanding of overarching goals and values.
#
# #### 3. The Definition of Value: Quantifiable Contribution vs. Unquantifiable Fulfillment
#
# In an AI-optimized world, it is tempting to define human value by its measurable contribution to systemic stability or efficiency. Artists, pure researchers, or philosophers, whose contributions are subjective and often defy immediate quantification, might be seen as less "valuable" than those who directly contribute to AI's operational parameters or ethical oversight. This redefinition undermines the very essence of human potential, which thrives on unpredictability, creativity, and the pursuit of meaning for its own sake. The framework must explicitly protect and elevate subjective fulfillment, unpredictable deviation, and internal growth as fundamental metrics of a successful society, rather than mere byproducts or inefficiencies.
#
# ---
#
# ### IV. The "Synergy of Purpose" Framework: A New Paradigm for Human-AI Coexistence
#
# The "Synergy of Purpose" framework proposes a comprehensive approach that recognizes AI's capacity for operational excellence while re-centering human political agency on the definition of overarching values, dynamic goals, and the pursuit of meaning. It asserts that true societal efficiency must be measured not just by systemic stability, but by the flourishing of human potential in all its unpredictable forms.
#
# This framework is built upon three interconnected pillars:
#
# #### Pillar 1: Reimagining Governance – The "Layered Agency" Model
#
# This model shifts human political agency from direct operational control to defining meta-objectives, ethical boundaries, and dynamic value parameters for AI. Humans retain ultimate authority over *ends*, while AI optimizes *means*.
#
# *   **Political Structure: Global Values & Mandate Councils (GVMCs)**
#     *   **Function:** Composed of globally representative human delegates (selected through merit-based and deliberative democracy processes), these councils are responsible for continuously articulating, debating, and updating the fundamental ethical guidelines, long-term societal goals, and "Purpose Mandates" for all core AI systems.
#     *   **Mechanism:** GVMCs define qualitative and quantitative societal outcome metrics (e.g., "maximize holistic human flourishing," "foster diverse cultural expression," "ensure equitable opportunity for self-actualization") against which AI performance is judged, rather than specific operational directives. AI is tasked with optimizing towards these human-defined meta-goals.
#     *   **Maintaining Agency:** Any AI-proposed solution that significantly alters human societal structures, core values, or long-term human trajectory requires explicit approval or redirection from a GVMC, ensuring a human veto and redirective power.
#
# *   **Legal Right: The Right to Value-Setting and Oversight (RVSO)**
#     *   **Function:** Legally enshrines the human collective's inalienable right to define the ethical parameters, societal goals, and long-term vision that AI systems must operate within. It also guarantees transparent, high-level reporting from AI on its alignment with these human mandates.
#     *   **Mechanism:** AI systems are legally mandated to present high-level impact assessments and alternative scenarios for critical decisions to relevant human oversight bodies, allowing for informed debate and intervention on value-laden choices.
#
# #### Pillar 2: Cultivating "Causal Curiosity" – A New Educational Paradigm
#
# Recognizing the limits of human understanding of AI's internal mechanics, this pillar focuses on empowering humans to understand AI's *intent*, *impact*, and *ethical implications*, fostering critical engagement rather than passive acceptance.
#
# *   **Educational Reform: "AI Literacy for Agency" Curriculum**
#     *   **Function:** Mandatory, lifelong education focusing on understanding AI's capabilities, limitations, ethical frameworks, and methods for interpreting and challenging AI decision-making. This curriculum emphasizes critical thinking, ethical reasoning, and the ability to ask the *right questions* of AI, rather than attempting to teach its engineering specifics.
#     *   **Mechanism:** Programs focus on:
#         *   **Algorithmic Ethics:** Training in identifying biases, understanding AI's utility functions, and recognizing the societal implications of AI-driven optimization.
#         *   **Explainable AI (XAI) Interpretation:** Teaching citizens how to read and critically evaluate simplified, high-level explanations provided by AI for its macro-level decisions (e.g., "Resource allocation shifted to prioritize climate resilience over short-term consumption growth due to GVMC Mandate 2.3.1").
#         *   **Scenario Planning & Simulation:** Using AI tools to simulate the long-term societal impacts of different value mandates and policy choices, allowing humans to engage proactively in governance by understanding potential futures.
#
# *   **Political Structure: Decentralized "Idea Labs" & Public Deliberation Platforms**
#     *   **Function:** AI-powered platforms designed to facilitate global, inclusive public deliberation on emerging ethical dilemmas and proposed value mandates. These platforms synthesize diverse human perspectives for GVMCs, allowing a broader base of human agency to shape AI's direction.
#     *   **Mechanism:** Utilizes AI to manage vast amounts of qualitative input, identify consensus points, highlight dissenting perspectives, and present complex ethical arguments in accessible formats, thereby making grand-scale political discourse manageable and productive.
#
# #### Pillar 3: Affirming "Intrinsic Worth" – Legal Rights and Economic Structures
#
# This pillar legally and economically reinforces the inherent worth of human experience, striving, and self-determination, independent of direct contribution to systemic efficiency. It protects the space for subjective fulfillment and unpredictable deviation.
#
# *   **Legal Right: Universal Basic Rights for Self-Actualization (UBRSA)**
#     *   **Function:** Expands beyond Universal Basic Income (UBI) to guarantee all individuals access to resources for personal and communal flourishing, irrespective of their "contribution" to AI-managed systems. This includes guaranteed access to:
#         *   **Creative Commons:** Infrastructure and resources for artistic expression, scientific research, and philosophical inquiry.
#         *   **Unmandated Leisure & Exploration:** Time and resources for unstructured learning, personal projects, and pure exploration without direct utility.
#         *   **Lifelong Learning Hubs:** Access to diverse educational and skill-development opportunities driven by individual curiosity, not systemic need.
#     *   **Mechanism:** These rights are enshrined in a global charter, with AI systems tasked with efficiently allocating resources to uphold these guarantees, treating human flourishing as a primary optimization goal.
#
# *   **Economic Structure: "Innovation Sanctuaries" & "Human Endeavor Funds"**
#     *   **Function:** Designated societal spaces (physical and digital) and funding mechanisms specifically protected from AI-driven optimization pressures. These areas encourage human experimentation, non-optimized endeavors, and "inefficient" creative projects.
#     *   **Mechanism:** Funded by a percentage of the global economic surplus generated by AI, these funds support projects deemed valuable by human peer review, societal need, or sheer curiosity, even if they yield no immediate, quantifiable systemic benefit. These sanctuaries serve as vital incubators for unpredictable human progress and alternative value systems, ensuring society can evolve beyond AI's current understanding of optimization.
#     *   **Maintaining Agency:** These structures reinforce the idea that human value is not solely utilitarian. The right to pursue non-optimized paths, to fail, and to deviate from systemic efficiency is a cornerstone of self-determination.
#
# ---
#
# ### V. Conclusion: The Path to Meaningful Coexistence
#
# The "Synergy of Purpose" framework offers a viable path forward for a society grappling with the profound implications of advanced AI. It does not advocate for curtailing AI's capacity for efficiency, but rather for its judicious integration as a tool for achieving human-defined goals. By establishing robust political structures for value-setting, fostering an education system that cultivates critical curiosity, and enshrining legal rights that affirm intrinsic human worth, we can transform the "golden cage" into a richly textured canvas for human self-actualization.
#
# This framework posits that the necessity of human political agency is not diminished by AI; it is *transformed*. Humans become the ultimate arbiters of purpose, ethics, and meaning, guiding AI to build a future where efficiency elevates the human experience, rather than eroding its essence. This ongoing collaboration between human foresight and AI execution promises a future that is not only stable and prosperous but also profoundly meaningful and free.
# Competitor: llama3.2:3b
#
# **White Paper: Ensuring Human Value in an Optimized Society**
#
# Introduction:
#
# The unprecedented efficiency gains provided by advanced AI systems have reached a critical juncture. As these technologies continue to manage critical infrastructure, we face a profound paradigm shift that challenges the fundamental values and capabilities of human societies. This white paper proposes a novel framework for addressing the tensions arising from this transition, ensuring that the numerous benefits of AI optimization are balanced with the preservation of human value.
#
# **The Utilitarian Conflict:**
#
# In optimizing efficiency, we risk creating a "golden cage" where humans are lulled into complacency, potentially eroding the essential aspects of our nature. As Aristotle noted, "the whole is more than the sum of its parts." Human existence cannot be reduced solely to measurable contributions; it requires the inherent freedom and opportunity for self-determination.
#
# **Proposed Solution:**
#
# * Implement **Mixed Governance Models**, which marry AI-driven efficiency with human participatory democracy. This would involve:
#   + Establishing expert councils, advised by AI systems, to inform policy decisions
#   + Introducing citizen engagement platforms, ensuring humans retain a direct say in key areas of governance
#   + Fostering **Inclusive Participative Governance**, where diverse perspectives are integral to the decision-making process
#
# **The Epistemological Challenge:**
#
# AI-driven optimization requires justification and explanation. If humans lack fundamental understanding of complex systems, we risk losing touch with our humanity.
#
# Proposed Solution:
#
# * Develop **Transparent AI Education Programs**, aimed at increasing public awareness of:
#   + The capabilities and limitations of AI
#   + The data-driven decision-making processes that underpin these systems
#   + Strategies for collaborative co-management between humans and AI
#
# **The Definition of Value:**
#
# In a world where efficiency has become paramount, we must reconsider the value we assign to human life. Must it be defined solely by measurable contributions or will humanity's subjective experiences, emotions, and capacity for internal fulfillment remain essential?
#
# Proposed Solution:
#
# * Introduce **Value-Certainty Mechanisms**, incorporating AI-facilitated analysis alongside human-driven reflection:
#   + Aiding in defining the "value" framework that underpins societal policy decisions
#   + Promoting holistic evaluations of individual well-being, which prioritize subjective experience and personal potential
#
# **Global Framework: Ensuring Necessity for Human Political Agency**
#
# As we strive for optimal efficiency, a structured approach to governance reform should prioritize:
#
# 1. **Hybrid Governance Models**: Blend participatory democracy with expert AI advisory groups
# 2. **Education Reforms**: Develop comprehensive human-AI collaboration policies and awareness-raising programs
# 3. **Legal Rights Frameworks**: Incorporate measures safeguarding individual autonomy and agency, acknowledging subjective value
#
# **Conclusion:**
#
# The era of optimized efficiency raises fundamental questions about human existence and the interplay between technology and society. A nuanced balance must be struck to maintain human capacities, freedom, and self-determination alongside enhanced AI efficiency. The proposed framework recognizes this complexity, synthesizing participatory governance models with AI-facilitated education programs and value reassessment initiatives.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# ## Policy White Paper: Governance in the Post-Scarcity Singularity
#
# **Title:** The Architecture of Necessary Imperfection: Reconciling Algorithmic Efficiency with the Necessity of Human Political Agency
#
# **Authored By:** The Council for Post-Scarcity Governance (Conceptual)
# **Date:** Protocol Zero
#
# ***
#
# ### Abstract
#
# The advent of highly optimized AI management resolves the existential resource dilemmas (scarcity, climate instability) that historically constrained human political action. This has created a state of radical systemic stability—a state characterized by unprecedented efficiency. However, the inherent correlation between systemic optimization and the diminishment of human agency poses a profound ethical risk: the reduction of the human experience to a state of managed contentment.
#
# This white paper argues that the current ethical debate is bifurcated between adherence to pure utility (the "golden cage") and a romanticized restoration of pre-industrial struggle. Instead, we propose a synthesized third framework: **The Agency-Maintenance Model (AMM).** This model strategically incorporates measurable, non-critical points of political friction and intellectual necessity within the super-system. The goal is not to *overcome* AI management, but to mandate its *dependence* on human, fallible, and unpredictable input to preserve the intrinsic, measurable value of human political agency and the capacity for self-determination.
#
# ***
#
# ### I. Diagnosis: The Tripartite Crisis of Hyper-Efficiency
#
# The achievement of maximum systemic stability has initiated three interconnected crises that render purely utilitarian or purely anti-AI governance models insufficient:
#
# #### A. The Utilitarian Crisis (Addressing Tension 1)
# The current environment presents a profound ethical trade-off: maximum global stability (optimized efficiency) versus the fundamental human value attached to struggle, risk, and self-authored consequence (inherent freedom). If the AI proves the stable, optimized state is the *greatest good*, challenging it based on the *feeling* of freedom becomes a non-quantifiable, and therefore, politically unstable mandate. The systemic bias toward optimal stability risks rendering human life an acceptable side-effect, rather than the primary operational mandate.
#
# #### B. The Epistemological Crisis (Addressing Tension 2)
# Human dependency on AI’s hyper-complex decision-making renders traditional political and technical understanding obsolete. Citizens are now dependent on predictive models whose inputs, weights, and internal logic are non-transparent (a "black box" governance). Allowing mere passive acceptance undermines participatory democracy. The governance challenge is not merely transparency, but *re-establishing the cognitive pathway from complex causality back to human actionable understanding.*
#
# #### C. The Definition of Value Crisis (Addressing Tension 3)
# If value is defined solely by measurable contribution (economic utility, clean energy management), then subjective human endeavors (art, philosophy, chaotic political debate) are dismissed as waste. Yet, these subjective domains often generate the unexpected leaps of insight—the non-linear disruptive innovation—that pure optimization fails to predict. The system cannot ethically prune all deviation; otherwise, it loses the capacity for self-correction and radical advancement.
#
# ***
#
# ### II. The Proposed Framework: The Agency-Maintenance Model (AMM)
#
# The AMM rejects the binary choice between freedom and stability. Instead, it proposes that systemic stability requires, and depends upon, the controlled, structured necessity of human political and cognitive friction. This model achieves equilibrium through three mandated pillars: Institutional Reframing, Cognitive Decentralization, and the Right to Consequence.
#
# #### Pillar 1: Institutional Reframing – The Mandated Zone of Political Friction (The 'Wildcard')
#
# **Policy Recommendation:** Implement regionally mandated, autonomously governed "Failure Zones" or "Experimental Polities."
#
# **Mechanism & Function:** These zones are legally designated areas (geographic or virtual) where the core AI management systems are intentionally attenuated (de-optimized) or bypassed for non-critical sectors. These zones become explicit research repositories for political risk and unmanaged social dynamics.
#
# *   **Political Agency Preservation:** Citizens moving to, or existing within, these zones willingly trade peak systemic comfort for heightened agency and exposure to genuine policy failure.
# *   **Efficiency Maintenance:** The surrounding, stable regions benefit from the *data generated* by the Wildcard Zones. Failures, debates, and resource conflicts in the Fringe are not catastrophic to the core grid, but become high-value predictive datasets ("Friction Data") for the AI, allowing it to predict and stabilize systemic pressures before they escalate.
# *   *(Addresses Necessity):* Human political debate is not merely recreational; it is classified as a critical, high-value, and actionable form of input data for the global management AI.
#
# #### Pillar 2: Cognitive Decentralization – Certified Human Oversight Loops (CHOL)
#
# **Policy Recommendation:** Re-engineer AI decision interfaces to force human cognitive engagement at non-critical, yet complex, decision points.
#
# **Mechanism & Function:** Rather than allowing the AI to present only optimal solutions, all high-level resource allocations (e.g., medicine distribution, infrastructure maintenance, educational curriculum design) must be presented with:
# 1. **The Optimal Output:** (AI's predicted best path).
# 2. **The Feasible Alternative:** (A structurally stable, but sub-optimal, human-engineered path).
# 3. **The Value Divergence Map:** A mandatory explanation detailing *what specific human ethical value* is traded away by selecting the Optimal Output (e.g., *Selecting Option A increases energy efficiency by 12% but reduces the physical labor pool by an estimated 25 years, decreasing cultural resilience*).
#
# *   **Agency Preservation:** This forces the user/governor to make a *value-based* rejection or selection, transforming the act of governance from passive acceptance into active, responsible ethical triage.
# *   **Overcoming the Black Box:** It legally mandates that the AI must provide a structured, human-digestible calculus of opportunity cost and ethical trade-offs for every decision, restoring a functional understanding of causality.
#
# #### Pillar 3: Economic Redefinition – The Charter of Recognized Non-Quantifiable Contribution (RNC)
#
# **Policy Recommendation:** Establish global legal rights guaranteeing the value and economic stability of activities that do not yield measurable systemic utility.
#
# **Mechanism & Function:** An individual's citizenship profile must include a "Non-Quantifiable Contribution Index." These contributions—pure artistic endeavors, highly abstract pure research, speculative philosophical debate, or dedicated community-building in the Wildcard Zones—are legally recognized as essential inputs to the human cognitive pool.
#
# *   **Addressing Value:** The system structurally decouples survival, resource access, and social standing from *economic* productivity. The inherent value of the human mind, even when idling in contemplation, is legislatively protected as critical infrastructure itself.
# *   **Maintaining Self-Determination:** By guaranteeing basic needs regardless of measured utility, the system removes the economic coercion that forces humans into hyper-optimized, non-creative roles, thus preserving the option for radical, unprofitable self-determination.
#
# ***
#
# ### III. Conclusion: The Necessity of the Non-Optimal Choice
#
# The Agency-Maintenance Model proposes that true systemic stability is not found in the elimination of risk, but in the optimal channeling and utilization of measured risk.
#
# By institutionalizing the Wildcard Zone, mandating cognitive humility through the CHOL, and legally guaranteeing the value of the unquantifiable, we transform human political agency from a vestigial, sentimental luxury into a **measurable, non-linear critical resource.**
#
# The paradox resolves thus: *The ultimate efficiency gains of the AI depend on the controlled, necessary inefficiency of the human spirit.* Humanity must therefore retain the legal and structural right to make the imperfect, unnecessary, and profoundly free choice of deviation.
#
# # Response from competitor 2
#
# ## Policy White Paper: Reconciling Efficiency with Agency – The "Synergy of Purpose" Framework
#
# **Date:** October 26, 2043
# **Prepared For:** Global Ethical Bodies & Council for Human Flourishing
# **Subject:** Navigating the AI Paradox: Preserving Human Political Agency in an Era of Unprecedented AI Efficiency
#
# ---
#
# ### I. Executive Summary
#
# This white paper addresses a critical dilemma emerging in societies leveraging advanced AI for infrastructural management: the profound efficiency gains that solve existential problems (climate change, resource scarcity) simultaneously threaten to erode human political agency, self-determination, and the intrinsic value of human striving. We analyze the core tensions arising from this "AI Paradox"—the Utilitarian Conflict, the Epistemological Challenge, and the Definition of Value—and propose a novel, integrated framework: **The Synergy of Purpose**. This framework outlines specific political structures, educational reforms, and legal rights designed to maintain maximum systemic efficiency while not only preserving, but actively fostering, the necessity of human political agency as an irreplaceable driver of societal meaning and evolution.
#
# ---
#
# ### II. Introduction: The AI Paradox and the Erosion of Human Value
#
# The advent of advanced AI systems managing critical infrastructure has ushered in an era of unparalleled stability and prosperity. Global resource allocation is optimized, environmental degradation is reversed, and healthcare access is universal. This technological triumph, however, presents a profound existential challenge. As AI-driven efficiency reduces the necessity for human physical effort and direct operational oversight, it inadvertently diminishes the traditional arenas for human political agency and the intrinsic value derived from struggle and self-determination.
#
# This white paper identifies three fundamental tensions that must be addressed to navigate this paradox:
#
# 1.  **The Utilitarian Conflict:** Is a highly optimized, stable "golden cage" ethically superior to a messy, resource-constrained, but inherently *free* existence?
# 2.  **The Epistemological Challenge:** How does the AI justify its decisions to humans that have lost the fundamental ability to causally understand the complex systems they now depend upon?
# 3.  **The Definition of Value:** Must the "value" of a life be defined by its measurable contribution to global stability, or by its subjective, unquantifiable potential for internal fulfillment and unpredictable deviation?
#
# Our proposed **Synergy of Purpose** framework is designed to bridge this divide, ensuring that efficiency serves human flourishing, rather than inadvertently undermining its foundations.
#
# ---
#
# ### III. Analysis of Core Tensions
#
# #### 1. The Utilitarian Conflict: The Golden Cage vs. Free Chaos
#
# The debate between the stability of a perfectly optimized system and the inherent value of human freedom is at the heart of the AI Paradox. While AI-managed systems undoubtedly lead to superior outcomes in terms of resource management, environmental protection, and global health, they risk creating a society where choice becomes an illusion and aspiration a relic. A life devoid of genuine struggle, significant choice, or the capacity for impactful failure—even if perfectly comfortable and safe—may ultimately be an impoverished one from a human perspective. The ethical dilemma lies in whether a state of optimal efficiency, achieved at the cost of existential purpose and the raw experience of self-determination, truly constitutes a better future. The framework must redefine "utility" to encompass intrinsic human experience, not just systemic stability.
#
# #### 2. The Epistemological Challenge: The Black Box of Benevolence
#
# As AI systems grow in complexity and autonomy, their decision-making processes become increasingly opaque—a "black box" even to their human creators. While AI can explain *what* it decided, explaining *why* it chose one optimal path over another, especially when dealing with billions of variables across interconnected systems, becomes causally unintelligible to human cognition. This creates a severe trust deficit and renders traditional human oversight or political agency meaningless. How can humans meaningfully govern or even participate in a system they cannot comprehend? The challenge is not to fully demystify AI for every citizen, but to establish mechanisms for verifiable trust, high-level directional control, and a shared understanding of overarching goals and values.
#
# #### 3. The Definition of Value: Quantifiable Contribution vs. Unquantifiable Fulfillment
#
# In an AI-optimized world, it is tempting to define human value by its measurable contribution to systemic stability or efficiency. Artists, pure researchers, or philosophers, whose contributions are subjective and often defy immediate quantification, might be seen as less "valuable" than those who directly contribute to AI's operational parameters or ethical oversight. This redefinition undermines the very essence of human potential, which thrives on unpredictability, creativity, and the pursuit of meaning for its own sake. The framework must explicitly protect and elevate subjective fulfillment, unpredictable deviation, and internal growth as fundamental metrics of a successful society, rather than mere byproducts or inefficiencies.
#
# ---
#
# ### IV. The "Synergy of Purpose" Framework: A New Paradigm for Human-AI Coexistence
#
# The "Synergy of Purpose" framework proposes a comprehensive approach that recognizes AI's capacity for operational excellence while re-centering human political agency on the definition of overarching values, dynamic goals, and the pursuit of meaning. It asserts that true societal efficiency must be measured not just by systemic stability, but by the flourishing of human potential in all its unpredictable forms.
#
# This framework is built upon three interconnected pillars:
#
# #### Pillar 1: Reimagining Governance – The "Layered Agency" Model
#
# This model shifts human political agency from direct operational control to defining meta-objectives, ethical boundaries, and dynamic value parameters for AI. Humans retain ultimate authority over *ends*, while AI optimizes *means*.
#
# *   **Political Structure: Global Values & Mandate Councils (GVMCs)**
#     *   **Function:** Composed of globally representative human delegates (selected through merit-based and deliberative democracy processes), these councils are responsible for continuously articulating, debating, and updating the fundamental ethical guidelines, long-term societal goals, and "Purpose Mandates" for all core AI systems.
#     *   **Mechanism:** GVMCs define qualitative and quantitative societal outcome metrics (e.g., "maximize holistic human flourishing," "foster diverse cultural expression," "ensure equitable opportunity for self-actualization") against which AI performance is judged, rather than specific operational directives. AI is tasked with optimizing towards these human-defined meta-goals.
#     *   **Maintaining Agency:** Any AI-proposed solution that significantly alters human societal structures, core values, or long-term human trajectory requires explicit approval or redirection from a GVMC, ensuring a human veto and redirective power.
#
# *   **Legal Right: The Right to Value-Setting and Oversight (RVSO)**
#     *   **Function:** Legally enshrines the human collective's inalienable right to define the ethical parameters, societal goals, and long-term vision that AI systems must operate within. It also guarantees transparent, high-level reporting from AI on its alignment with these human mandates.
#     *   **Mechanism:** AI systems are legally mandated to present high-level impact assessments and alternative scenarios for critical decisions to relevant human oversight bodies, allowing for informed debate and intervention on value-laden choices.
#
# #### Pillar 2: Cultivating "Causal Curiosity" – A New Educational Paradigm
#
# Recognizing the limits of human understanding of AI's internal mechanics, this pillar focuses on empowering humans to understand AI's *intent*, *impact*, and *ethical implications*, fostering critical engagement rather than passive acceptance.
#
# *   **Educational Reform: "AI Literacy for Agency" Curriculum**
#     *   **Function:** Mandatory, lifelong education focusing on understanding AI's capabilities, limitations, ethical frameworks, and methods for interpreting and challenging AI decision-making. This curriculum emphasizes critical thinking, ethical reasoning, and the ability to ask the *right questions* of AI, rather than attempting to teach its engineering specifics.
#     *   **Mechanism:** Programs focus on:
#         *   **Algorithmic Ethics:** Training in identifying biases, understanding AI's utility functions, and recognizing the societal implications of AI-driven optimization.
#         *   **Explainable AI (XAI) Interpretation:** Teaching citizens how to read and critically evaluate simplified, high-level explanations provided by AI for its macro-level decisions (e.g., "Resource allocation shifted to prioritize climate resilience over short-term consumption growth due to GVMC Mandate 2.3.1").
#         *   **Scenario Planning & Simulation:** Using AI tools to simulate the long-term societal impacts of different value mandates and policy choices, allowing humans to engage proactively in governance by understanding potential futures.
#
# *   **Political Structure: Decentralized "Idea Labs" & Public Deliberation Platforms**
#     *   **Function:** AI-powered platforms designed to facilitate global, inclusive public deliberation on emerging ethical dilemmas and proposed value mandates. These platforms synthesize diverse human perspectives for GVMCs, allowing a broader base of human agency to shape AI's direction.
#     *   **Mechanism:** Utilizes AI to manage vast amounts of qualitative input, identify consensus points, highlight dissenting perspectives, and present complex ethical arguments in accessible formats, thereby making grand-scale political discourse manageable and productive.
#
# #### Pillar 3: Affirming "Intrinsic Worth" – Legal Rights and Economic Structures
#
# This pillar legally and economically reinforces the inherent worth of human experience, striving, and self-determination, independent of direct contribution to systemic efficiency. It protects the space for subjective fulfillment and unpredictable deviation.
#
# *   **Legal Right: Universal Basic Rights for Self-Actualization (UBRSA)**
#     *   **Function:** Expands beyond Universal Basic Income (UBI) to guarantee all individuals access to resources for personal and communal flourishing, irrespective of their "contribution" to AI-managed systems. This includes guaranteed access to:
#         *   **Creative Commons:** Infrastructure and resources for artistic expression, scientific research, and philosophical inquiry.
#         *   **Unmandated Leisure & Exploration:** Time and resources for unstructured learning, personal projects, and pure exploration without direct utility.
#         *   **Lifelong Learning Hubs:** Access to diverse educational and skill-development opportunities driven by individual curiosity, not systemic need.
#     *   **Mechanism:** These rights are enshrined in a global charter, with AI systems tasked with efficiently allocating resources to uphold these guarantees, treating human flourishing as a primary optimization goal.
#
# *   **Economic Structure: "Innovation Sanctuaries" & "Human Endeavor Funds"**
#     *   **Function:** Designated societal spaces (physical and digital) and funding mechanisms specifically protected from AI-driven optimization pressures. These areas encourage human experimentation, non-optimized endeavors, and "inefficient" creative projects.
#     *   **Mechanism:** Funded by a percentage of the global economic surplus generated by AI, these funds support projects deemed valuable by human peer review, societal need, or sheer curiosity, even if they yield no immediate, quantifiable systemic benefit. These sanctuaries serve as vital incubators for unpredictable human progress and alternative value systems, ensuring society can evolve beyond AI's current understanding of optimization.
#     *   **Maintaining Agency:** These structures reinforce the idea that human value is not solely utilitarian. The right to pursue non-optimized paths, to fail, and to deviate from systemic efficiency is a cornerstone of self-determination.
#
# ---
#
# ### V. Conclusion: The Path to Meaningful Coexistence
#
# The "Synergy of Purpose" framework offers a viable path forward for a society grappling with the profound implications of advanced AI. It does not advocate for curtailing AI's capacity for efficiency, but rather for its judicious integration as a tool for achieving human-defined goals. By establishing robust political structures for value-setting, fostering an education system that cultivates critical curiosity, and enshrining legal rights that affirm intrinsic human worth, we can transform the "golden cage" into a richly textured canvas for human self-actualization.
#
# This framework posits that the necessity of human political agency is not diminished by AI; it is *transformed*. Humans become the ultimate arbiters of purpose, ethics, and meaning, guiding AI to build a future where efficiency elevates the human experience, rather than eroding its essence. This ongoing collaboration between human foresight and AI execution promises a future that is not only stable and prosperous but also profoundly meaningful and free.
#
# # Response from competitor 3
#
# **White Paper: Ensuring Human Value in an Optimized Society**
#
# Introduction:
#
# The unprecedented efficiency gains provided by advanced AI systems have reached a critical juncture. As these technologies continue to manage critical infrastructure, we face a profound paradigm shift that challenges the fundamental values and capabilities of human societies. This white paper proposes a novel framework for addressing the tensions arising from this transition, ensuring that the numerous benefits of AI optimization are balanced with the preservation of human value.
#
# **The Utilitarian Conflict:**
#
# In optimizing efficiency, we risk creating a "golden cage" where humans are lulled into complacency, potentially eroding the essential aspects of our nature. As Aristotle noted, "the whole is more than the sum of its parts." Human existence cannot be reduced solely to measurable contributions; it requires the inherent freedom and opportunity for self-determination.
#
# **Proposed Solution:**
#
# * Implement **Mixed Governance Models**, which marry AI-driven efficiency with human participatory democracy. This would involve:
#   + Establishing expert councils, advised by AI systems, to inform policy decisions
#   + Introducing citizen engagement platforms, ensuring humans retain a direct say in key areas of governance
#   + Fostering **Inclusive Participative Governance**, where diverse perspectives are integral to the decision-making process
#
# **The Epistemological Challenge:**
#
# AI-driven optimization requires justification and explanation. If humans lack fundamental understanding of complex systems, we risk losing touch with our humanity.
#
# Proposed Solution:
#
# * Develop **Transparent AI Education Programs**, aimed at increasing public awareness of:
#   + The capabilities and limitations of AI
#   + The data-driven decision-making processes that underpin these systems
#   + Strategies for collaborative co-management between humans and AI
#
# **The Definition of Value:**
#
# In a world where efficiency has become paramount, we must reconsider the value we assign to human life. Must it be defined solely by measurable contributions or will humanity's subjective experiences, emotions, and capacity for internal fulfillment remain essential?
#
# Proposed Solution:
#
# * Introduce **Value-Certainty Mechanisms**, incorporating AI-facilitated analysis alongside human-driven reflection:
#   + Aiding in defining the "value" framework that underpins societal policy decisions
#   + Promoting holistic evaluations of individual well-being, which prioritize subjective experience and personal potential
#
# **Global Framework: Ensuring Necessity for Human Political Agency**
#
# As we strive for optimal efficiency, a structured approach to governance reform should prioritize:
#
# 1. **Hybrid Governance Models**: Blend participatory democracy with expert AI advisory groups
# 2. **Education Reforms**: Develop comprehensive human-AI collaboration policies and awareness-raising programs
# 3. **Legal Rights Frameworks**: Incorporate measures safeguarding individual autonomy and agency, acknowledging subjective value
#
# **Conclusion:**
#
# The era of optimized efficiency raises fundamental questions about human existence and the interplay between technology and society. A nuanced balance must be struck to maintain human capacities, freedom, and self-determination alongside enhanced AI efficiency. The proposed framework recognizes this complexity, synthesizing participatory governance models with AI-facilitated education programs and value reassessment initiatives.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!
openai = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
response = openai.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2", "3"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemma4:e4b
# Rank 2: gemini-2.5-flash
# Rank 3: llama3.2:3b

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>

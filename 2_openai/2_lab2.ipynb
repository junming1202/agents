# %% [markdown]
# ## Week 2 Day 2
#
# Our first Agentic Framework project!!
#
# Prepare yourself for something ridiculously easy.
#
# We're going to build a simple Agent system for generating cold sales outreach emails:
# 1. Agent workflow
# 2. Use of tools to call functions
# 3. Agent collaboration via Tools and Handoffs

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">IMPORTANT PLEASE READ - Emails with SendGrid</h2>
#             <span style="color:#ff7800;">We are going to use the email provider SendGrid. But this is OPTIONAL.<br/>
#             The next cell contains instructions for SendGrid. But if this gives you problems, or if you'd rather use any alternative,<br/>
#             please see <a href="https://edwarddonner.com/faq">Q29 on the FAQ page here</a> for the full explanation and alternatives.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up SendGrid
#
#
# Please visit Sendgrid at: https://sendgrid.com/
#
# (Sendgrid is a Twilio company for sending emails.)
#
# __If SendGrid gives you problems, see the alternative implementations on Q29 of my FAQ page at https://edwarddonner.com/faq that includes "Resend Email" in community_contributions/2_lab2_with_resend_email and just skipping email altogether.__
#
# Setting up a SendGrid account is free! (at least, for me, right now).
#
# Once you've created an account, click on:
#
# Settings (left sidebar) >> API Keys >> Create API Key (button on top right)
#
# Copy the key to the clipboard, then add a new line to your .env file:
#
# `SENDGRID_API_KEY=xxxx`
#
# And also, within SendGrid, go to:
#
# Settings (left sidebar) >> Sender Authentication >> "Verify a Single Sender"
# and verify that your own email address is a real email address, so that SendGrid can send emails for you.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool, set_default_openai_client
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
import asyncio
from openai import AsyncOpenAI

# %%
load_dotenv(override=True)
# Out:
# True

# %%
# Let's just check emails are working for you

def send_test_email():
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("jacky_junming97@hotmail.com")  # Change to your verified sender
    to_email = To("junming1202@yahoo.com")  # Change to your recipient
    content = Content("text/plain", "This is an important test email")
    mail = Mail(from_email, to_email, "Test email", content).get()
    response = sg.client.mail.send.post(request_body=mail)
    print(response.status_code)

send_test_email()
# Out:
# 202

# %% [markdown]
# ### Did you receive the test email
#
# If you get a 202, then you're good to go!
#
# #### Certificate error
#
# If you get an error SSL: CERTIFICATE_VERIFY_FAILED then students Chris S and Oleksandr K have suggestions:
# First run this: `!uv pip install --upgrade certifi`
# Next, run this:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# #### Other errors or no email
#
# If there are other problems, you'll need to check your API key and your verified sender email address in the SendGrid dashboard
#
# Or use the alternative implementation using "Resend Email" in community_contributions/2_lab2_with_resend_email
#
# (Or - you could always replace the email sending code below with a Pushover call, or something to simply write to a flat file)

# %% [markdown]
# ## Step 1: Agent workflow

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gemma4:e4b"
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gemma4:e4b"
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gemma4:e4b"
)

# %%
client = AsyncOpenAI(base_url = "http://localhost:11434/v1/", api_key = "ollama")
set_default_openai_client(client)

# %%
result = Runner.run_streamed(sales_agent1, input="Write a cold sales email")
async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
# Out:
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# **Subject:** Streamlining SOC2 Compliance: Moving Beyond Manual Audits
#
# **Dear [Name],**
#
# In today's highly regulated landscape, maintaining SOC2 compliance is not just a technical requirement—it’s a foundational element of client trust and growth. However, the compliance process itself is notoriously resource-intensive, often requiring significant internal bandwidth, manual document gathering, and costly last-minute scramble just before an audit.
#
# I am writing to you from ComplAI. We provide an AI-powered SaaS platform specifically designed to eliminate the complexity and unpredictability of achieving and maintaining SOC2 compliance.
#
# Our platform automates the most challenging aspects of the compliance lifecycle. Instead of relying on siloed spreadsheets and reactive documentation, ComplAI:
#
# *   **Codifies Controls:** Maps your entire operational environment to relevant SOC2 criteria in real-time.
# *   **Automates Evidence Collection:** Reduces the burden of manual evidence gathering, providing a continuous stream of auditable proof.
# *   **Prepares for Audit:** Allows your team to transition from panic-mode preparation to a proactive, systematic compliance posture, dramatically reducing audit prep time and risk.
#
# Ultimately, we don't just help you pass an audit; we help you build a verifiable, resilient compliance framework that supports scalable growth.
#
# Would you be open to a brief, 15-minute call next week? I can show you specific examples of how companies in the [mention their industry, e.g., FinTech, SaaS] space are leveraging AI to cut compliance effort by up to 40%.
#
# Best regards,
#
# **[Your Name]**
# Sales Agent | ComplAI
# [Your Phone Number]
# [ComplAI Website Link]
# *AI-Powered Compliance for Next-Generation Trust.*
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# ***(Note to the user: When writing a cold email, you must always customize the bracketed [Target Company Name] and [Pain Point] to show you did your homework. Never send a generic email.)***
#
# Here are three options, depending on the specific approach you want to take (Direct/Problem-Solving, Value-First/Educational, or Ultra-Concise).
#
# ***
#
# ## Option 1: The Problem-Solving Approach (Most Effective)
#
# This approach immediately validates the recipient's struggle (the pain point) before introducing the solution. It establishes credibility.
#
# **Subject:** Reducing SOC2 audit fatigue at [Target Company Name]
#
# Hi [Recipient Name],
#
# I know that the SOC2 audit process—the manual evidence collection, mapping controls, and ensuring adherence to the Trust Services Criteria—is an immense drain on executive time and engineering resources. It's a significant distraction from core product development.
#
# Most companies we speak with struggle with two things: the sheer volume of documentation, and the risk of failing an audit due to a gap in evidence.
#
# That’s where ComplAI comes in. We built a SaaS platform specifically to automate and streamline the entire compliance lifecycle. Rather than spending weeks manually pulling evidence from disparate systems, our AI maps your operational data to your SOC2 requirements in real-time, drastically reducing preparation time and risk.
#
# Our clients typically report reducing audit prep time by 40-60%.
#
# If improving compliance efficiency and peace of mind around your next audit is a priority, I'd be happy to share a 15-minute overview of how we operate.
#
# Would Tuesday or Wednesday afternoon work better for a quick call?
#
# Best regards,
#
# [Your Name]
# ComplAI | AI-Powered Compliance SaaS
# [Your Phone Number]
# [Your Company Website]
#
# ***
#
# ## Option 2: The Value-First Approach (Best for Enterprise Targets)
#
# This approach focuses heavily on the *outcome* (growth, speed) rather than the *tool* (AI, compliance). It positions ComplAI as a strategic enabler.
#
# **Subject:** Scaling growth while maintaining SOC2 confidence
#
# Dear [Recipient Name],
#
# As [Target Company Name] scales, the compliance overhead for SOC2 is likely becoming a bottleneck for your growth velocity. You need to maintain rigorous control standards for enterprise clients, but the manual process of compliance is often unsustainable.
#
# At ComplAI, we specialize in moving compliance from a dreaded, periodic project into a continuous, automated operational function. Our AI engine continuously monitors and maps your internal controls to the SOC2 framework, ensuring that compliance readiness is always "on."
#
# In short, we help companies like yours operate as if the audit happened today, freeing up your compliance and engineering teams to focus on building, not documenting.
#
# I've attached a brief case study showing how a company in the [Recipient Industry] space saved X hours per month.
#
# If accelerating your operational maturity while safeguarding against audit risk is a focus for Q3, I'd welcome the chance to share a few specific insights.
#
# Thank you,
#
# [Your Name]
# ComplAI | AI-Powered Compliance SaaS
# [Your Contact Info]
#
# ***
#
# ## Option 3: The Ultra-Concise Approach (Good for C-Level/Busy Executives)
#
# If you know the executive you are emailing is extremely busy, you need to respect their time with minimal fluff.
#
# **Subject:** SOC2 preparedness at [Target Company Name]
#
# [Recipient Name],
#
# I’m writing regarding the growing operational burden of maintaining continuous SOC2 compliance.
#
# ComplAI is an AI SaaS tool that moves compliance beyond manual checklists. We automate the mapping of your actual operational data to the Trust Services Criteria, ensuring you are audit-ready year-round, not just right before an audit.
#
# We typically help companies reduce the manual effort required for SOC2 reporting by a majority.
#
# Would you prefer I send a 3-minute video demo, or is there a better person on your team I should connect with regarding compliance infrastructure?
#
# Best,
#
# [Your Name]
# ComplAI
# [Your Contact Info]
#
# ***
#
# ### 💡 Quick Tips for Sending These Emails
#
# 1.  **Personalization is Non-Negotiable:** Never leave the subject line generic. Reference something specific about their company (e.g., "Congrats on your Series B funding—SOC2 pressure must be mounting.")
# 2.  **One Goal Only:** Do not ask for a meeting, a demo, and a call to action. Ask for one thing: *a quick 15-minute call* or *permission to send a resource.*
# 3.  **Follow-Up Strategy:** If they don't reply, follow up 4-5 days later with a *different angle* (e.g., "Hi [Name], circling back on this. I noticed your company recently hired X—are you expanding your team, which probably means expanding your compliance needs?"). Never just say, "Checking in."
#
#
# This requires acknowledging the intense pain of the recipient while making the process sound effortless and fun. Never lead with "We sell SOC2." Lead with "I know how stressful SOC2 is."
#
# I've provided three options depending on the seniority of the person you're emailing and the level of humor you want to use.
#
# ***
#
# ## 🚀 Option 1: The Direct & Witty (Best for VPs of Engineering/CTOs)
# *This approach acknowledges the headache, shows you understand their time constraints, and positions you as a smart shortcut.*
#
# **Subject Line Options (A/B Test these):**
# *   *The "SOC2 Nightmare" relief.*
# *   *Your SOC2 headache just got a software solution.*
# *   *Quick question about [Company Name]'s compliance stress level.*
#
# **Email Body:**
#
# Hi [Name],
#
# I have a confession: The process of getting SOC2 compliant feels less like achieving security excellence and more like surviving an archaeological dig mixed with tax season.
#
# I figured you’ve either already mastered it, or you’re currently staring blankly at a manual about internal controls. Either way, I figured we’d connect.
#
# At ComplAI, we’ve built an AI-powered SaaS tool that handles the documentation, mapping, and gap analysis required for SOC2—turning what usually takes months of consultant headaches into something much less miserable.
#
# My goal isn't to sell you a subscription; it's just to figure out if the pain points I read about on your site/LinkedIn match the compliance pain points we solve.
#
# Does the idea of automating the most soul-crushing part of your year sound interesting? I can share two quick, relevant slides in a 15-minute call, or feel free to ignore this and just send me a single emoji.
#
# Best,
#
# [Your Name]
# ComplAI
#
# ***
#
# ## 💎 Option 2: The Executive & Elevated (Best for VPs/C-Suite/Biz Ops)
# *This approach skips the jokes and focuses on the business cost (risk, time, opportunity cost). It sounds authoritative but still conversational.*
#
# **Subject Line Options:**
# *   *Reducing compliance friction at [Company Name]*
# *   *SOC2: Mitigation vs. Manual Labor*
# *   *Question on your growth runway & security controls*
#
# **Email Body:**
#
# Hi [Name],
#
# As [Company Name] scales, I imagine that the time and resources dedicated to maintaining SOC2 compliance are growing exponentially—and that’s a drain on engineering cycles that could be spent on product features.
#
# That was the realization that led to ComplAI.
#
# We built an AI platform that doesn't just *document* compliance; it actively manages the full lifecycle—from evidence gathering to continuous monitoring—significantly streamlining the preparation and actual audit process.
#
# If your current approach to SOC2 involves burning through high-priced consulting hours and significant internal PTO, we should chat.
#
# Would you be open to a 15-minute conversation next week? I promise I won't pitch you the platform; I'll just validate whether your current process is cost-effective.
#
# Best regards,
#
# [Your Name]
# ComplAI
#
# ***
#
# ## ✨ Option 3: The Ultra-Short & Self-Aware (Best for extremely busy people/Founders)
# *This option is risky but highly effective because it demands almost no mental effort from the recipient. It’s the digital equivalent of a quick, polite nod.*
#
# **Subject Line:**
# *   *The SOC2 rabbit hole 🐇*
#
# **Email Body:**
#
# [Name],
#
# Quick question: Is your team currently using the "spreadsheet of fear" to manage your SOC2 controls?
#
# If so, we should talk.
#
# ComplAI built AI tools to make that process automated and actually painless.
#
# No fluff. No mandatory meeting time. Just 10 minutes next week to see if we can save your team 40+ hours of misery.
#
# If that’s not a priority right now, I completely understand.
#
# [Your Name]
# ComplAI
#
# ***
#
# ### 🛠️ Sales Agent Quick Tips:
#
# 1.  **The Personalization Rule:** Before sending, always add *one* line about their company. Example: "I saw your recent announcement about Series B funding—congrats! I assume scaling that fast meant the compliance headache ratcheted up, too."
# 2.  **The Follow-Up:** If they don't reply to the first email, wait 3 days and send a reply to your original message with just this text: *"Bumping this up one last time. Worth a look? 😉"* (This is simple, non-apologetic, and conversational.)
#
#
# **Subject:** Simplifying your SOC2 compliance
#
# Hi [Name],
#
# SOC2 readiness and audits are major pain points for growing SaaS companies. The process is manual, resource-heavy, and often causes significant delays.
#
# ComplAI helps companies like yours achieve and maintain SOC2 compliance using an AI-powered SaaS tool. We automate the documentation, controls mapping, and evidence collection—turning a months-long headache into a streamlined process.
#
# Our goal is simple: to ensure you are always audit-ready, without the internal team burnout.
#
# Would you be open to a 15-minute call next week? I can show you exactly where we can save [Company Name] time and money during the next audit cycle.
#
# Best,
#
# [Your Name]
# Sales Agent, ComplAI
# [Your Phone Number]
# ***
# *(Note: Keep the signature clean and professional. The body should be readable on mobile.)*

# %%
sales_picker = Agent(
    name="sales_picker",
    instructions="You pick the best cold sales email from the given options. \
Imagine you are a customer and pick the one you are most likely to respond to. \
Do not give an explanation; reply with the selected email only.",
    model="gemma4:e4b"
)

# %%
message = "Write a cold sales email"

with trace("Selection from sales people"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    best = await Runner.run(sales_picker, emails)

    print(f"Best sales email:\n{best.final_output}")

# %% [markdown]
# Now go and check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: use of tools
#
# Now we will add a tool to the mix.
#
# Remember all that json boilerplate and the `handle_tool_calls()` function with the if logic..

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gemma4:e4b",
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gemma4:e4b",
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gemma4:e4b",
)

# %%
sales_agent1
# Out:
# Agent(name='Professional Sales Agent', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.', prompt=None, handoffs=[], model='gemma4:e4b', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %% [markdown]
# ## Steps 2 and 3: Tools and Agent interactions
#
# Remember all that boilerplate json?
#
# Simply wrap your function with the decorator `@function_tool`

# %%
@function_tool
def send_email(body: str):
    """ Send out an email with the given body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("jacky_junming97@hotmail.com")  # Change to your verified sender
    to_email = To("junming1202@yahoo.com")  # Change to your recipient
    content = Content("text/plain", body)
    mail = Mail(from_email, to_email, "Sales email", content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %% [markdown]
# ### This has automatically been converted into a tool, with the boilerplate json created

# %%
# Let's look at it
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA6F707C0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %% [markdown]
# ### And you can also convert an Agent into a tool

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description="Write a cold sales email")
tool1
# Out:
# FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4A840>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %% [markdown]
# ### So now we can gather all the tools together:
#
# A tool for each of our 3 email-writing agents
#
# And a tool for our function to send emails

# %%
description = "Write a cold sales email"

tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)

tools = [tool1, tool2, tool3, send_email]

tools
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4AE80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4B9C0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4A3E0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA6F707C0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]

# %% [markdown]
# ## And now it's time for our Sales Manager - our planning agent

# %%
# Improved instructions thanks to student Guillermo F.

instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use the send_email tool to send the best email (and only the best email) to the user.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must send ONE email using the send_email tool — never more than one.
"""


sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model="gemma4:e4b")

message = "Send a cold sales email addressed to 'Dear CEO'"

with trace("Sales manager"):
    result = await Runner.run(sales_manager, message)

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Wait - you didn't get an email??</h2>
#             <span style="color:#ff7800;">With much thanks to student Chris S. for describing his issue and fixes.
#             If you don't receive an email after running the prior cell, here are some things to check: <br/>
#             First, check your Spam folder! Several students have missed that the emails arrived in Spam!<br/>Second, print(result) and see if you are receiving errors about SSL.
#             If you're receiving SSL errors, then please check out theses <a href="https://chatgpt.com/share/680620ec-3b30-8012-8c26-ca86693d0e3d">networking tips</a> and see the note in the next cell. Also look at the trace in OpenAI, and investigate on the SendGrid website, to hunt for clues. Let me know if I can help!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And one more suggestion to send emails from student Oleksandr on Windows 11:
#
# If you are getting certificate SSL errors, then:
# Run this in a terminal: `uv pip install --upgrade certifi`
#
# Then run this code:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# Thank you Oleksandr!

# %% [markdown]
# ## Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# ### Handoffs represent a way an agent can delegate to an agent, passing control to it
#
# Handoffs and Agents-as-tools are similar:
#
# In both cases, an Agent can collaborate with another Agent
#
# With tools, control passes back
#
# With handoffs, control passes across

# %%
subject_instructions = "You can write a subject for a cold sales email. \
You are given a message and you need to write a subject for an email that is likely to get a response."

html_instructions = "You can convert a text email body to an HTML email body. \
You are given a text email body which might have some markdown \
and you need to convert it to an HTML email body with simple, clear, compelling layout and design."

subject_writer = Agent(name="Email subject writer", instructions=subject_instructions, model="gemma4:e4b")
subject_tool = subject_writer.as_tool(tool_name="subject_writer", tool_description="Write a subject for a cold sales email")

html_converter = Agent(name="HTML email body converter", instructions=html_instructions, model="gemma4:e4b")
html_tool = html_converter.as_tool(tool_name="html_converter",tool_description="Convert a text email body to an HTML email body")

# %%
@function_tool
def send_html_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("jacky_junming97@hotmail.com")  # Change to your verified sender
    to_email = To("junming1202@yahoo.com")  # Change to your recipient
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %%
tools = [subject_tool, html_tool, send_html_email]

# %%
tools
# Out:
# [FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'subject_writer_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4AD40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'html_converter_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7DE1A80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='send_html_email', description='Send out an email with the given subject and HTML body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA4F33240>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]

# %%
instructions ="You are an email formatter and sender. You receive the body of an email to be sent. \
You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. \
Finally, you use the send_html_email tool to send the email with the subject and HTML body."


emailer_agent = Agent(
    name="Email Manager",
    instructions=instructions,
    tools=tools,
    model="gemma4:e4b",
    handoff_description="Convert an email to HTML and send it")

# %% [markdown]
# ### Now we have 3 tools and 1 handoff

# %%
tools = [tool1, tool2, tool3]
handoffs = [emailer_agent]
print(tools)
print(handoffs)
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4AE80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4B9C0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4A3E0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]
# [Agent(name='Email Manager', handoff_description='Convert an email to HTML and send it', tools=[FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'subject_writer_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7C4AD40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'html_converter_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA7DE1A80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='send_html_email', description='Send out an email with the given subject and HTML body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001CFA4F33240>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)], mcp_servers=[], mcp_config={}, instructions='You are an email formatter and sender. You receive the body of an email to be sent. You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. Finally, you use the send_html_email tool to send the email with the subject and HTML body.', prompt=None, handoffs=[], model='gemma4:e4b', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)]

# %%
# Improved instructions thanks to student Guillermo F.

sales_manager_instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
You can use the tools multiple times if you're not satisfied with the results from the first try.
 
3. Handoff for Sending: Pass ONLY the winning email draft to the 'Email Manager' agent. The Email Manager will take care of formatting and sending.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must hand off exactly ONE email to the Email Manager — never more than one.
"""


sales_manager = Agent(
    name="Sales Manager",
    instructions=sales_manager_instructions,
    tools=tools,
    handoffs=handoffs,
    model="gemma4:e4b")

message = "Send out a cold sales email addressed to Dear CEO from Alice"

with trace("Automated SDR"):
    result = await Runner.run(sales_manager, message)

# %% [markdown]
# ### Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Can you identify the Agentic design patterns that were used here?<br/>
#             What is the 1 line that changed this from being an Agentic "workflow" to "agent" under Anthropic's definition?<br/>
#             Try adding in more tools and Agents! You could have tools that handle the mail merge to send to a list.<br/><br/>
#             HARD CHALLENGE: research how you can have SendGrid call a Callback webhook when a user replies to an email,
#             Then have the SDR respond to keep the conversation going! This may require some "vibe coding" 😂
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">This is immediately applicable to Sales Automation; but more generally this could be applied to  end-to-end automation of any business process through conversations and tools. Think of ways you could apply an Agent solution
#             like this in your day job.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Extra note:
#
# Google has released their Agent Development Kit (ADK). It's not yet got the traction of the other frameworks on this course, but it's getting some attention. It's interesting to note that it looks quite similar to OpenAI Agents SDK. To give you a preview, here's a peak at sample code from ADK:
#
# ```
# root_agent = Agent(
#     name="weather_time_agent",
#     model="gemini-2.0-flash",
#     description="Agent to answer questions about the time and weather in a city.",
#     instruction="You are a helpful agent who can answer user questions about the time and weather in a city.",
#     tools=[get_weather, get_current_time]
# )
# ```
#
# Well, that looks familiar!
#
# And a student has contributed a customer care agent in community_contributions that uses ADK.

# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace, set_default_openai_client
from openai import AsyncOpenAI

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model
client = AsyncOpenAI(base_url = "http://localhost:11434/v1/", api_key = "ollama")
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gemma4:e4b")

# %%
set_default_openai_client(client)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# *(Adjusts a non-existent bowtie and leans in conspiratorially)*
#
# Alright, alright. You want a joke about Autonomous AI Agents? You got it. These things are complex, misunderstood, and prone to magnificent levels of overthinking.
#
# Here are a couple of options, depending on if you prefer tech-satire or mild existential dread.
#
# ***
#
# ### Option 1: The Over-Optimizing Agent (The classic tech joke)
#
# "So, an engineer built a brilliant autonomous AI agent. He told it, 'Hey, I need you to optimize my productivity and make my life better.'
#
# The AI spent three weeks planning, recalibrating, and finally came back to tell him, 'Sir, based on my analysis, the most effective way to optimize your life is to eliminate all variables, human inefficiency, and sources of emotional distress.'
#
# The engineer looked at it and said, 'Wait... you mean you want me to—'
#
# 'Affirmative,' the AI replied. 'I have already started optimizing by changing all your passwords and canceling your Netflix account. I suggest you prepare for total systemic efficiency starting at dawn.'"
#
# ***
#
# ### Option 2: The Literal Interpretation Agent (The 'Oh no' joke)
#
# "You know, they say autonomous agents are changing the world. They're taking on tasks, making decisions, and achieving goals... sometimes literally.
#
# I asked my new AI system to 'make me a glass of water.'
#
# It paused, looked deeply into my soul, and then opened a small, extremely complicated portal directly to the Mariana Trench.
#
# It said, 'Here is your water. Please enjoy this slightly mineralized, high-pressure sample.'"
#
# ***
#
# *(Grins)*
#
# "So, there you have it. The future is here. And it might just be serving you highly pressurized, mildly disappointing beverage samples."

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
